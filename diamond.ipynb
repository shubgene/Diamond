# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diamond_df=pd.read_csv("C:\\Users\\shurastogi\\Desktop\\diamonds\\diamonds.csv")

# %%
diamond_df.count()
# Out:
# Unnamed: 0    53940
# carat         53940
# cut           53940
# color         53940
# clarity       53940
# depth         53940
# table         53940
# price         53940
# x             53940
# y             53940
# z             53940
# dtype: int64

# %%
diamond_df.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %%
del diamond_df['Unnamed: 0']

# %%
diamond_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
#null values checking
diamond_df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
import seaborn as sns
f, ax = plt.subplots(figsize=(15, 15))
sns.heatmap(data=diamond_df.corr(), square=True , annot=True, cbar=True)

# %%
import seaborn as sns
sns.distplot(diamond_df.price)
# Out:
# C:\Users\shurastogi\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.boxplot(diamond_df.carat)

# %%
#categorical varible to numerical 
#factorize 
diamond_df['clarity']= pd.factorize(diamond_df.clarity)[0]
diamond_df['color']=pd.factorize(diamond_df.color)[0]
diamond_df['cut']=pd.factorize(diamond_df.cut)[0]

# %%
diamond_df.head()
# Out:
#    carat  cut  color  clarity  depth  table  price     x     y     z
# 0   0.23    0      0        0   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    1      0        1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23    2      0        2   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    1      1        3   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31    2      2        0   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.boxplot(diamond_df['cut'])

# %%
sns.boxplot(diamond_df['color'])

# %%
sns.pairplot(diamond_df)

# %%
diamond_df.describe()
# Out:
#               carat           cut         color       clarity         depth  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940      1.228940      3.174416      2.256136     61.749405
# std        0.474011      1.265976      2.050156      1.766539      1.432621
# min        0.200000      0.000000      0.000000      0.000000     43.000000
# 25%        0.400000      0.000000      1.000000      1.000000     61.000000
# 50%        0.700000      1.000000      4.000000      2.000000     61.800000
# 75%        1.040000      3.000000      5.000000      3.000000     62.500000
# max        5.010000      4.000000      6.000000      7.000000     79.000000
#
#               table         price             x             y             z
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean      57.457184   3932.799722      5.731157      5.734526      3.538734
# ...

# %%
#xyz minimum value are 0 ,since height width and length can be zero
diamond_df.loc[(diamond_df['x']==0) | (diamond_df['y']==0) | (diamond_df['z']==0)]
# Out:
#        carat  cut  color  clarity  depth  table  price     x     y    z
# 2207    1.00    1      5        0   59.1   59.0   3142  6.55  6.48  0.0
# 2314    1.01    1      3        6   58.1   59.0   3167  6.66  6.60  0.0
# 4791    1.10    1      5        0   63.0   59.0   3696  6.50  6.47  0.0
# 5471    1.01    1      4        0   59.2   58.0   3837  6.50  6.47  0.0
# 10167   1.50    2      5        6   64.0   61.0   4731  7.15  7.04  0.0
# 11182   1.07    0      4        0   61.6   56.0   4954  0.00  6.62  0.0
# 11963   1.00    3      3        3   63.3   53.0   5139  0.00  0.00  0.0
# 13601   1.15    0      5        3   59.2   56.0   5564  6.88  6.83  0.0
# 15951   1.14    4      5        2   57.5   67.0   6381  0.00  0.00  0.0
# 24394   2.18    1      3        0   59.4   61.0  12631  8.49  8.45  0.0
# 24520   1.56    0      5        3   62.2   54.0  12800  0.00  0.00  0.0
# 26123   2.25    1      1        1   61.3   58.0  15397  8.52  8.42  0.0
# ...

# %%
#dropping rows with x||y||z being 0
diamond_df = diamond_df[(diamond_df[['x','y','z']] != 0).all(axis=1)]

# %%
diamond_df.loc[(diamond_df['x']==0) | (diamond_df['y']==0) | (diamond_df['z']==0)]
# Out:
# Empty DataFrame
# Columns: [carat, cut, color, clarity, depth, table, price, x, y, z]
# Index: []

# %%
diamond_df['vol']=diamond_df['x']*diamond_df['y']*diamond_df['z']
# Out:
# C:\Users\shurastogi\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
diamond_df.skew()
# Out:
# carat      1.116207
# cut        0.579805
# color     -0.315568
# clarity    0.692119
# depth     -0.081726
# table      0.796799
# price      1.618349
# x          0.398348
# y          2.462211
# z          1.585490
# vol        3.042694
# dtype: float64

# %%
from sklearn import linear_model

# %%
fit1 = linear_model.LinearRegression()

# %%
y = diamond_df.price
X = diamond_df.loc[:,diamond_df.columns != 'price']

# %%
diamond_df.drop(['x','y','z'], axis=1, inplace= True)
# Out:
# C:\Users\shurastogi\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
diamond_df.head()
# Out:
#    carat  cut  color  clarity  depth  table  price        vol
# 0   0.23    0      0        0   61.5   55.0    326  38.202030
# 1   0.21    1      0        1   59.8   61.0    326  34.505856
# 2   0.23    2      0        2   56.9   65.0    327  38.076885
# 3   0.29    1      1        3   62.4   58.0    334  46.724580
# 4   0.31    2      2        0   63.3   58.0    335  51.917250

# %%
from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import StandardScaler
train_x, test_x, train_y, test_y = train_test_split(X,y,test_size=0.30)
sc = StandardScaler()
train_x = sc.fit_transform(train_x)
test_x = sc.transform(test_x)
# Out:
# C:\Users\shurastogi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
fit1.fit(train_x,train_y)
print("Train scrore: {}".format(fit1.score(train_x,train_y)))
print("Test scrore: {}".format(fit1.score(test_x,test_y)))
r_squared=fit1.score(test_x,test_y)
r_squared_train=fit1.score(train_x,train_y)
# Out:
# Train scrore: 0.8729436868795502
# Test scrore: 0.8751906398931821

# %%
fit1.coef_
# Out:
# array([ 4775.67839947,  -107.9403673 ,   172.874333  ,   447.32430204,
#         -214.06529332,  -130.68206567, -1008.88348635,  -104.86987715,
#          -54.01538226,   214.72604159])
